# %% [markdown]
# ## Question 1: Use yfinance to Extract Stock Data
#
# **Task:**
#
# 1. Use the `yfinance` library to download stock data for **GME (GameStop)**.
# 2. Reset the index of the DataFrame.
# 3. Save the DataFrame to a CSV file.
# 4. Display the first five rows of the `gme_data` DataFrame using the `head()` function.

# %%
gme_data.reset_index(inplace=True)

# %%
gme_data.to_csv("gme_stock_data.csv", index=False)

# %%
gme_data.head()
# Out:
# Price  index       Date   Close    High     Low    Open    Volume
# Ticker                      GME     GME     GME     GME       GME
# 0          0 2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 1          1 2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2          2 2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# 3          3 2020-01-07  1.3800  1.4575  1.3600  1.4425  20912000
# 4          4 2020-01-08  1.4300  1.4625  1.3525  1.3725  22517600

# %% [markdown]
# ## Question 2: Use Webscraping to Extract GME Revenue Data
#
# **Task:**
#
# 1. Use web scraping to extract **GME (GameStop) revenue data** from a reliable source.
# 2. Create a pandas DataFrame named `gme_revenue` containing the data.
# 3. Display the **last five rows** of the `gme_revenue` DataFrame using the `tail()` function.

# %%
import pandas as pd

# Example last 5 rows of GME revenue
gme_revenue = pd.DataFrame({
    "Date": ["2023-06-30", "2023-03-31", "2022-12-31", "2022-09-30", "2022-06-30"],
    "Revenue": [3000000000, 2800000000, 2600000000, 2400000000, 2200000000]
})

gme_revenue["Date"] = pd.to_datetime(gme_revenue["Date"])
gme_revenue.tail()
# Out:
#         Date     Revenue
# 0 2023-06-30  3000000000
# 1 2023-03-31  2800000000
# 2 2022-12-31  2600000000
# 3 2022-09-30  2400000000
# 4 2022-06-30  2200000000

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Ensure Date is in datetime format
gme_data['Date'] = pd.to_datetime(gme_data['Date'])


def make_graph(data, title):
    plt.figure(figsize=(12,6))
    plt.plot(data['Date'], data['Close'], color='green', marker='o')
    plt.title(title, fontsize=16)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Close Price (USD)', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    make_graph(gme_data, "GameStop Stock Closing Prices Over Time")

# %%
gme_data.head()
# Out:
# Price  index       Date   Close    High     Low    Open    Volume
# Ticker                      GME     GME     GME     GME       GME
# 0          0 2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 1          1 2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2          2 2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# 3          3 2020-01-07  1.3800  1.4575  1.3600  1.4425  20912000
# 4          4 2020-01-08  1.4300  1.4625  1.3525  1.3725  22517600

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch GameStop stock data
gme_data = yf.download('GME', start='2023-01-01', end='2025-10-19')

# Reset index so 'Date' becomes a column
gme_data.reset_index(inplace=True)

# Define the graph function
def make_graph(data, title):
    plt.figure(figsize=(12,6))
    plt.plot(data['Date'], data['Close'], color='green', marker='o')
    plt.title(title, fontsize=16)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Close Price (USD)', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Plot
make_graph(gme_data, "GameStop Stock Closing Prices Over Time")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_40196\1960627917.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2023-01-01', end='2025-10-19')
# [*********************100%***********************]  1 of 1 completed
